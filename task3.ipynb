# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk(r'C:\Users\mounika\Desktop\techno task 3'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\mounika\Desktop\techno task 3\city_attributes.csv
# C:\Users\mounika\Desktop\techno task 3\humidity.csv
# C:\Users\mounika\Desktop\techno task 3\pressure.csv
# C:\Users\mounika\Desktop\techno task 3\temperature.csv
# C:\Users\mounika\Desktop\techno task 3\weather_description.csv
# C:\Users\mounika\Desktop\techno task 3\wind_direction.csv
# C:\Users\mounika\Desktop\techno task 3\wind_speed.csv

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %%
print(os.listdir(r'C:\Users\mounika\Desktop\techno task 3'))
# Out:
# ['city_attributes.csv', 'humidity.csv', 'pressure.csv', 'temperature.csv', 'weather_description.csv', 'wind_direction.csv', 'wind_speed.csv']

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]]
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) // nGraphPerRow
    plt.figure(num=None, figsize=(6 * nGraphPerRow, 8 * nGraphRow), dpi=80, facecolor='w', edgecolor='k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation=90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad=1.0, w_pad=1.0, h_pad=1.0)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include=[np.number])
    df = df.dropna(axis='columns')
    df = df.loc[:, df.nunique() > 1]
    columnNames = list(df)
    if len(columnNames) > 10:
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k=1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center',
                          va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
# Load the city_attributes.csv file
nRowsRead = 1000
df1 = pd.read_csv(r'C:\Users\mounika\Desktop\techno task 3\city_attributes.csv', delimiter=',', nrows=nRowsRead)
df1.dataframeName = 'city_attributes.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 36 rows and 4 columns

# %%
df1.head(6)
# Out:
#             City        Country   Latitude   Longitude
# 0      Vancouver         Canada  49.249660 -123.119339
# 1       Portland  United States  45.523449 -122.676208
# 2  San Francisco  United States  37.774929 -122.419418
# 3        Seattle  United States  47.606209 -122.332069
# 4    Los Angeles  United States  34.052231 -118.243683
# 5      San Diego  United States  32.715328 -117.157257

# %%
plotPerColumnDistribution(df1, 10, 5)

# %%
plotScatterMatrix(df1, 6, 15)

# %%
nRowsRead = 1000
df2 = pd.read_csv(r'C:\Users\mounika\Desktop\techno task 3\city_attributes.csv', delimiter=',', nrows=nRowsRead)
df2.dataframeName = 'humidity.csv'
nRow, nCol = df2.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 36 rows and 4 columns

# %%
df2.head(6)
# Out:
#             City        Country   Latitude   Longitude
# 0      Vancouver         Canada  49.249660 -123.119339
# 1       Portland  United States  45.523449 -122.676208
# 2  San Francisco  United States  37.774929 -122.419418
# 3        Seattle  United States  47.606209 -122.332069
# 4    Los Angeles  United States  34.052231 -118.243683
# 5      San Diego  United States  32.715328 -117.157257

# %%
nRowsRead = 1000
df3 = pd.read_csv(r'C:\Users\mounika\Desktop\techno task 3\pressure.csv', delimiter=',', nrows=nRowsRead)
df3.dataframeName = 'pressure.csv'
nRow, nCol = df3.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 37 columns

# %%
plotPerColumnDistribution(df3, 10, 5)

# %%
nRowsRead = 1000
df4 = pd.read_csv(r'C:\Users\mounika\Desktop\techno task 3\temperature.csv', delimiter=',', nrows=nRowsRead)
df4.dataframeName = 'temperature.csv'
nRow, nCol = df4.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 37 columns

# %%
plotPerColumnDistribution(df4, 10, 5)

# %%
nRowsRead = 1000
df5 = pd.read_csv(r'C:\Users\mounika\Desktop\techno task 3\weather_description.csv', delimiter=',', nrows=nRowsRead)
df5.dataframeName = 'weather_description.csv'
nRow, nCol = df5.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 37 columns

# %%
plotPerColumnDistribution(df5, 10, 5)

# %%
nRowsRead = 1000
df6 = pd.read_csv(r'C:\Users\mounika\Desktop\techno task 3\wind_direction.csv', delimiter=',', nrows=nRowsRead)
df6.dataframeName = 'wind_direction.csv'
nRow, nCol = df6.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 37 columns

# %%
plotPerColumnDistribution(df6, 10, 5)

# %%
nRowsRead = 1000
df7 = pd.read_csv(r'C:\Users\mounika\Desktop\techno task 3\wind_speed.csv', delimiter=',', nrows=nRowsRead)
df7.dataframeName = 'wind_speed.csv'
nRow, nCol = df7.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 37 columns

# %%
plotPerColumnDistribution(df7, 10, 5)
